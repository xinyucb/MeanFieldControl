# %%
#!/usr/bin/env python3
"""
Simple Path Dependent McKean Vlasov Control Solver Test
"""

import torch
import matplotlib.pyplot as plt
import torch.multiprocessing as mp
import numpy as np
from datetime import datetime
import pandas as pd
from plot_functions import *
# Set multiprocessing start method
mp.set_start_method('spawn', force=True)

# Set default tensor type
d_type = torch.float32
torch.set_default_dtype(d_type)
import warnings
warnings.filterwarnings("ignore")
from Param import DefaultParams
from high_dim_path_model import HighDimPathModel
from avg_path_model import AvgPathModel

from Path_MKV_Solver import PathMKV


# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
"""Main function to run the MKV solver test."""

print("=" * 50)
print("Path Dependent Solver Test (Low Dimension)")
print("=" * 50)

# Set random seed for reproducibility
np.random.seed(2025)

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")


control_types = ["XtAt"] # ["X", "B"]
d_list = [1]
model_ = "TDAvg"
model_dic = {"TDTer": HighDimPathModel,
                "TDAvg": AvgPathModel}
choice = model_dic[model_]
for d_ in d_list: 
    for control in control_types:
        print(f"Training begins d = {str(d_)}, control =", control)
        # ================================================================= ===========
        # Parameters Setup 
        # ============================================================================
        params = DefaultParams(d=d_, control_type=control).params
        setup = choice(params, delay=0) 
        model = PathMKV(setup, params)
        # Get current time
        now = datetime.now()
        # Format as string: YYYYMMDD_HHMM
        timestamp = now.strftime("_%Y%m%d%H%M")
        # Example filename
        model.filename = model_ + "_delay0_" + model.filename + "_" + timestamp
        model.train(plot=True)
        now = datetime.now()
        timestamp2 = now.strftime("_%H%M")
        model.filename += timestamp2

        print(f"model filename: {model.filename}")

        # ============================================================================
        # Save the model
        # ============================================================================
        print("\nSaving model...")
        model.save_NN()
        
        # ============================================================================
        # Save results
        # ============================================================================
        print("\nSaving loss results...")
        model.save_loss()
        
        
        print(f"Loss data saved as: outputLoss/{model.filename}_val_loss.csv")
        print(f"Model saved as: outputNN/{model.filename}")
# Out:
# ==================================================
# Path Dependent Solver Test (Low Dimension)
# ==================================================
# Using device: cuda
# Training begins d = 1, control = XtAt
# {'B': 102, 'X': 52, 'Xt': 2, 'XtAt': 3}
# ⚠️ Pre-trained model not found at outputNN/.pth. Starting from scratch.
# current filename: path_XtAt_d_1
# 100%|██████████| 50/50 [00:12<00:00,  3.98it/s]
# plotting
# 0.49868354 0.6872627
# It: 0, loss_training: 2.2298, loss_validation: 2.2206
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# plotting
# 0.5689446 0.7158806
# It: 1, loss_training: 2.0498, loss_validation: 2.1227
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# plotting
# 0.56033593 0.658398
# It: 2, loss_training: 1.9710, loss_validation: 2.0727
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.97it/s]
# plotting
# 0.59671474 0.59822667
# It: 3, loss_training: 2.0532, loss_validation: 1.9478
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  4.09it/s]
# plotting
# 0.64423436 0.5966057
# It: 4, loss_training: 1.8947, loss_validation: 1.8573
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# plotting
# 0.69122046 0.5342286
# It: 5, loss_training: 1.9951, loss_validation: 1.6931
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# plotting
# 0.70331436 0.59058994
# It: 6, loss_training: 1.7752, loss_validation: 1.7387
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.97it/s]
# plotting
# 0.7143705 0.5390055
# It: 7, loss_training: 1.6335, loss_validation: 1.6665
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.99it/s]
# plotting
# 0.777714 0.4237732
# It: 8, loss_training: 1.5600, loss_validation: 1.4302
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.93it/s]
# plotting
# 0.7448132 0.4529945
# It: 9, loss_training: 1.6010, loss_validation: 1.5027
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.95it/s]
# plotting
# 0.7293693 0.46141362
# It: 10, loss_training: 1.5507, loss_validation: 1.5373
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.89it/s]
# plotting
# 0.8069358 0.48222592
# It: 11, loss_training: 1.5067, loss_validation: 1.4460
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# plotting
# 0.7971657 0.4811986
# It: 12, loss_training: 1.5094, loss_validation: 1.4405
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# plotting
# 0.8366379 0.46444842
# It: 13, loss_training: 1.2985, loss_validation: 1.3760
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# plotting
# 0.8204618 0.3539229
# It: 14, loss_training: 1.2390, loss_validation: 1.2552
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.88it/s]
# plotting
# 0.81631374 0.42476258
# It: 15, loss_training: 1.3948, loss_validation: 1.3306
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.93it/s]
# plotting
# 0.85529506 0.3897225
# It: 16, loss_training: 1.2633, loss_validation: 1.2353
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.96it/s]
# plotting
# 0.84281397 0.3543276
# It: 17, loss_training: 1.2568, loss_validation: 1.2232
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.85it/s]
# plotting
# 0.876757 0.35273
# It: 18, loss_training: 1.2256, loss_validation: 1.1521
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.84it/s]
# plotting
# 0.92557025 0.30618584
# It: 19, loss_training: 1.1708, loss_validation: 1.0130
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.79it/s]
# plotting
# 0.8721908 0.38632506
# It: 20, loss_training: 1.2120, loss_validation: 1.1988
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.64it/s]
# plotting
# 0.93090373 0.31262255
# It: 21, loss_training: 1.0692, loss_validation: 1.0059
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.72it/s]
# plotting
# 0.9303469 0.28729028
# It: 22, loss_training: 1.0151, loss_validation: 0.9745
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.84it/s]
# plotting
# 0.95562136 0.2623655
# It: 23, loss_training: 0.9532, loss_validation: 0.9032
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.90it/s]
# plotting
# 0.98309046 0.28559694
# It: 24, loss_training: 0.9024, loss_validation: 0.8873
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.72it/s]
# plotting
# 0.9943855 0.23748817
# It: 25, loss_training: 0.9363, loss_validation: 0.8114
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.77it/s]
# plotting
# 0.95240164 0.22252545
# It: 26, loss_training: 0.8574, loss_validation: 0.8476
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.45it/s]
# plotting
# 0.9559419 0.2920461
# It: 27, loss_training: 0.9494, loss_validation: 0.9119
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.85it/s]
# plotting
# 0.9594311 0.30737054
# It: 28, loss_training: 0.8141, loss_validation: 0.9515
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.88it/s]
# plotting
# 0.98950845 0.24831183
# It: 29, loss_training: 0.7954, loss_validation: 0.8195
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.79it/s]
# plotting
# 1.1809758 0.34202027
# It: 30, loss_training: 0.8178, loss_validation: 1.0046
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.87it/s]
# plotting
# 1.0106509 0.16907397
# It: 31, loss_training: 0.7009, loss_validation: 0.6782
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.85it/s]
# plotting
# 0.97366595 0.26301193
# It: 32, loss_training: 0.6492, loss_validation: 0.8444
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.53it/s]
# plotting
# 1.0292807 0.2065321
# It: 33, loss_training: 0.6850, loss_validation: 0.6971
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.49it/s]
# plotting
# 1.0327628 0.19060645
# It: 34, loss_training: 0.5404, loss_validation: 0.6677
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.76it/s]
# plotting
# 1.076871 0.23417245
# It: 35, loss_training: 0.5888, loss_validation: 0.7083
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.85it/s]
# plotting
# 1.0614384 0.16729544
# It: 36, loss_training: 0.6548, loss_validation: 0.5937
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:12<00:00,  3.99it/s]
# plotting
# 1.0379863 0.20649
# It: 37, loss_training: 0.5956, loss_validation: 0.6712
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.72it/s]
# plotting
# 1.0993035 0.12797467
# It: 38, loss_training: 0.5792, loss_validation: 0.4754
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.52it/s]
# plotting
# 1.0999217 0.15784869
# It: 39, loss_training: 0.5629, loss_validation: 0.5245
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.52it/s]
# plotting
# 1.0737263 0.13036475
# It: 40, loss_training: 0.6793, loss_validation: 0.5087
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:15<00:00,  3.32it/s]
# plotting
# 1.0940777 0.13546164
# It: 41, loss_training: 0.5420, loss_validation: 0.4958
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.48it/s]
# plotting
# 1.0627178 0.18531284
# It: 42, loss_training: 0.5303, loss_validation: 0.5991
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:15<00:00,  3.13it/s]
# plotting
# 1.0987812 0.13125555
# It: 43, loss_training: 0.4991, loss_validation: 0.4695
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.33it/s]
# plotting
# 1.0918908 0.15217885
# It: 44, loss_training: 0.5435, loss_validation: 0.5312
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.47it/s]
# plotting
# 1.0850314 0.16027893
# It: 45, loss_training: 0.6020, loss_validation: 0.5322
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.46it/s]
# plotting
# 1.1032941 0.12364223
# It: 46, loss_training: 0.4479, loss_validation: 0.4545
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.39it/s]
# plotting
# 1.1282209 0.11171597
# It: 47, loss_training: 0.5261, loss_validation: 0.3929
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.41it/s]
# plotting
# 1.1179802 0.11487409
# It: 48, loss_training: 0.3819, loss_validation: 0.4100
# Updated learning rate: 0.001
# 100%|██████████| 50/50 [00:16<00:00,  3.09it/s]
# plotting
# 1.1212342 0.115324095
# It: 49, loss_training: 0.4339, loss_validation: 0.4212
# Updated learning rate: 0.001
# model filename: TDAvg_delay0_path_XtAt_d_1__202511181417_1428
#
# Saving model...
# The path exists: /home/lix/MeanFieldControl/PathDependent/outputNN
# ✅ The NN has been saved in /home/lix/MeanFieldControl/PathDependent/outputNN/TDAvg_delay0_path_XtAt_d_1__202511181417_1428.pth
#
# Saving loss results...
# Directory already exists: /home/lix/MeanFieldControl/PathDependent/outputLoss
# ✅ Loss data saved to: /home/lix/MeanFieldControl/PathDependent/outputLoss/TDAvg_delay0_path_XtAt_d_1__202511181417_1428_train_loss.csv
# ✅ Loss data saved to: /home/lix/MeanFieldControl/PathDependent/outputLoss/TDAvg_delay0_path_XtAt_d_1__202511181417_1428_val_loss.csv
# Loss data saved as: outputLoss/TDAvg_delay0_path_XtAt_d_1__202511181417_1428_val_loss.csv
# Model saved as: outputNN/TDAvg_delay0_path_XtAt_d_1__202511181417_1428

# %%
print(f"Loss data saved as: outputLoss/{model.filename}_val_loss.csv")
print(f"Model saved as: outputNN/{model.filename}")
# Out:
# Loss data saved as: outputLoss/TDAvg_delay0_path_XtAt_d_1__202511181417_1428_val_loss.csv
# Model saved as: outputNN/TDAvg_delay0_path_XtAt_d_1__202511181417_1428

# %%
_ = model.simulation_paths(plot=True)
# Out:
# plotting
# 1.1414272 0.08630463
